# %% [markdown]
# ## Content Understanding - "READ" API for Document Analysis

# %% [markdown]
# ![content_understanding](../Images/content-understanding.png)

# %% [markdown]
# #### Installing Utilities and Libraries

# %%
# %pip install python-dotenv azure-ai-contentunderstanding==1.1.0 azure-identity
# Out:
# Requirement already satisfied: python-dotenv in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (1.2.1)
# Requirement already satisfied: azure-ai-contentunderstanding in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (1.1.0)
# Requirement already satisfied: azure-identity in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (1.26.0b1)
# Requirement already satisfied: isodate>=0.6.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-contentunderstanding) (0.7.2)
# Requirement already satisfied: azure-core>=1.37.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-contentunderstanding) (1.40.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from azure-ai-contentunderstanding) (4.15.0)
# Requirement already satisfied: cryptography>=2.5 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: msal>=1.30.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from azure-core>=1.37.0->azure-ai-contentunderstanding) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-contentunderstanding) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-contentunderstanding) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-contentunderstanding) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.21.0->azure-core>=1.37.0->azure-ai-contentunderstanding) (2025.11.12)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages)
# WARNING: Ignoring invalid distribution ~ygments (C:\Users\Asus\AppData\Roaming\Python\Python313\site-packages)
#
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# #### Setting up the Environment Variables

# %%
from azure.ai.contentunderstanding import ContentUnderstandingClient
from azure.ai.contentunderstanding.models import AnalysisInput, AnalysisResult
from azure.core.credentials import AzureKeyCredential
from azure.core.exceptions import AzureError
from azure.identity import DefaultAzureCredential
from dotenv import load_dotenv
import os
import json
import sys

load_dotenv()

endpoint = os.getenv("FOUNDRY_AI_SERVICES_ENDPOINT")
api_key = os.getenv("FOUNDRY_AI_SERVICES_KEY")
api_version = "2025-11-01"
analyzer_id = "prebuilt-read"

print("Endpoint:", endpoint)
print("API Key:", api_key)

# %% [markdown]
# #### Initializing the Content Understanding Client

# %%
# Set up Content Understanding client.
credential = AzureKeyCredential(api_key) if api_key and "{{FOUNDRY_AI_SERVICES_KEY}}" not in api_key else DefaultAzureCredential()
client = ContentUnderstandingClient(endpoint=endpoint, credential=credential, api_version=api_version)

# %% [markdown]
# #### Analyze Invoice using the "READ" API

# %%
# Set the file URL
file_url = "https://github.com/kuljotSB/AI-901-Azure-AI-Fundamentals/Content-Understanding/Prebuilt-Read-API/Samples/invoice.pdf"

# Start analyzing an invoice using the "READ" API
print("\nAnalyzing invoice using the 'READ' API...")

try:
    poller = client.begin_analyze(
        analyzer_id=analyzer_id,
        inputs = [AnalysisInput(uri=file_url)]
    )

    result: AnalysisResult = poller.result()

except AzureError as err:
    print("Error analyzing document:", {err.message})
    sys.exit(1)
except Exception as ex:
    print("An unexpected error occurred:", {str(ex)})
    sys.exit(1)

# %% [markdown]
# #### Display Results for Invoice Analysis

# %%
# [START output_result]
print("=" * 50)
print("Analysis result:")
print("=" * 50 + "\n")

result_str = json.dumps(result.as_dict(), indent=2)
ret_lines = result_str.splitlines()

print("\n".join(ret_lines[:100]))  # Print only the first 100 lines for brevity
# [END output_result]
